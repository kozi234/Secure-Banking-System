# %%
import os

# Get current working directory
print("📂 Current Directory:", os.getcwd())

# List all files in the directory
print("📄 Files in Directory:", os.listdir(os.getcwd()))
# Out:
# 📂 Current Directory: C:\Users\kiboz\SecureBankingProject
# 📄 Files in Directory: ['.ipynb_checkpoints', '.pytest_cache', 'account.py', 'Assignment #3.ipynb', 'Covid_Data_25Rows.xlsx', 'CSC3028_JohnK_Assignment #3.ipynb', 'models', 'national-history.csv', 'policy.py', 'tests', 'test_account.py', 'test_transaction.py', 'test_user.py', 'transaction.py', 'user.py']

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("national-history.csv")

# Display the first 25 rows
df.head(25)
# Out:
#           date     death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0   2021-03-07  515151.0            842          45475.0          8134.0
# 1   2021-03-06  514309.0           1680          45453.0          8409.0
# 2   2021-03-05  512629.0           2221          45373.0          8634.0
# 3   2021-03-04  510408.0           1743          45293.0          8970.0
# 4   2021-03-03  508665.0           2449          45214.0          9359.0
# 5   2021-03-02  506216.0           1728          45084.0          9465.0
# 6   2021-03-01  504488.0           1241          44956.0          9595.0
# 7   2021-02-28  503247.0           1051          44907.0          9802.0
# 8   2021-02-27  502196.0           1847          44875.0         10114.0
# 9   2021-02-26  500349.0           2141          44791.0         10466.0
# 10  2021-02-25  498208.0           3138          44636.0         10846.0
# 11  2021-02-24  495070.0           2447          44534.0         11026.0
# ...

# %%
# Load the saved Excel file
df_new = pd.read_excel("Covid_Data_25Rows.xlsx", nrows=15, engine="openpyxl")

# Display 15 rows from the Excel file
print(df_new)
# Out:
#           date   death  deathIncrease  inIcuCumulative  inIcuCurrently  \
# 0   2021-03-07  515151            842            45475            8134
# 1   2021-03-06  514309           1680            45453            8409
# 2   2021-03-05  512629           2221            45373            8634
# 3   2021-03-04  510408           1743            45293            8970
# 4   2021-03-03  508665           2449            45214            9359
# 5   2021-03-02  506216           1728            45084            9465
# 6   2021-03-01  504488           1241            44956            9595
# 7   2021-02-28  503247           1051            44907            9802
# 8   2021-02-27  502196           1847            44875           10114
# 9   2021-02-26  500349           2141            44791           10466
# 10  2021-02-25  498208           3138            44636           10846
# 11  2021-02-24  495070           2447            44534           11026
# ...
